# %% [markdown]
# # Stage 2 ProxyOpt - SP Eval Analyzer & Visualizer

# %%
import numpy as np
import shutil
import os
from pathlib import Path
import pandas as pd
from IPython.display import display, HTML
import matplotlib.pyplot as plt
import cv2
import warnings

pd.set_option('display.max_rows', 500)
# %cd /home/boat/proxyISP/pytorch-superpoint
# Out:
# /home/boat/proxyISP/pytorch-superpoint
# /home/boat/miniconda3/envs/proxyopt/lib/python3.12/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %% [markdown]
# ### Specify Evaluation Directories

# %%
eval_log_dirs = [
    "logs/eval_ll_v16.1_original",
    "logs/eval_ll_train_v16.1_lowlight_lr0.0005_5000"
]

# %%
objects = {}
for d in eval_log_dirs:
    objects[os.path.basename(d)] = (np.load(Path(d) / "predictions" / "result.npz"))
objects
# Out:
# {'eval_ll_v16.1_original': NpzFile 'logs/eval_ll_v16.1_original/predictions/result.npz' with keys: repeatability, localization_err, correctness, homography_thresh, mscore...,
#  'eval_ll_train_v16.1_lowlight_lr0.0005_5000': NpzFile 'logs/eval_ll_train_v16.1_lowlight_lr0.0005_5000/predictions/result.npz' with keys: repeatability, localization_err, correctness, homography_thresh, mscore...}

# %% [markdown]
# ### Single Value Metrics

# %%
for k in ["repeatability", "localization_err", "mscore", "mAP"]:
    print(f"{k}:")
    df = pd.DataFrame()
    for key, object in objects.items():
        value = object[k].mean(axis = 0)
        df[key] = np.array([value])
    display(df)
# Out:
# repeatability:
#    eval_ll_v16.1_original  eval_ll_train_v16.1_lowlight_lr0.0005_5000
# 0                0.576366                                    0.580558
# localization_err:
#    eval_ll_v16.1_original  eval_ll_train_v16.1_lowlight_lr0.0005_5000
# 0                1.204681                                     1.22582
# mscore:
#    eval_ll_v16.1_original  eval_ll_train_v16.1_lowlight_lr0.0005_5000
# 0                0.261993                                    0.262641
# mAP:
#    eval_ll_v16.1_original  eval_ll_train_v16.1_lowlight_lr0.0005_5000
# 0                0.669651                                    0.669576

# %% [markdown]
# ### Homography Correctness @k

# %%
def show_homography_correctness(obj, only_diff = False, row_id_to_filter = None, plot_image = False, plot= "matching"):
    first_name = next(iter(obj))
    thresh = obj[first_name]["homography_thresh"]
    longest_name_len = max([len(name) for name in obj])
    for k,t in enumerate(thresh):
        print(f"homography correctness @{t}\n mean:")
        df = pd.DataFrame()
        total = []
        for eval_id, (name, v) in enumerate(obj.items()):
            correctness_at_k = v["correctness"][:, k]
            df[f" [{eval_id}] {name[-15:]}"] = correctness_at_k
            total.append(correctness_at_k)
            print("\t" + name," " * (longest_name_len - len(name)), correctness_at_k.mean())
        total = np.stack(total)
        df["is_diff"] = (total.sum(axis = 0) < total.shape[0]) & (total.sum(axis = 0) > 0)
        if row_id_to_filter is not None:
            df = df.loc[row_id_to_filter]
        if only_diff:
            df = df[df["is_diff"] == True]
        print()
        display(df)

    if plot_image and row_id_to_filter is None:
        warnings.warn("Image will not be plotted, row_id_to_filter is None, plotting all images will slow down the notebook")
    if plot_image and row_id_to_filter is not None:
        for index, row in df.iterrows():
            print(f"pair {index}")
            for d in eval_log_dirs:
                base_path = Path(d) / "predictions"
                if plot == "matching":
                    image_filepath = base_path / "matching" / f"{index}m.png"
                if plot == "warping":
                    image_filepath = base_path / "warping" / f"{index}.png"
                image_image = cv2.imread(str(image_filepath))
                plt.imshow(image_image[:,:,::-1])
                plt.xlabel(f"\t{os.path.basename(d)}")
                plt.show()
            print("")

only_diff = False
row_id_to_filter =  [20, 34, 40, 44, 62]
plot_image = True
plot = "matching"

show_homography_correctness(objects, only_diff = only_diff, row_id_to_filter = row_id_to_filter, plot_image = plot_image, plot=plot)
# Out:
# homography correctness @1
#  mean:
# 	eval_ll_v16.1_original                      0.0625
# 	eval_ll_train_v16.1_lowlight_lr0.0005_5000  0.1125
#      [0] _v16.1_original   [1] t_lr0.0005_5000  is_diff
# 20                 False                  True     True
# 34                  True                 False     True
# 40                 False                  True     True
# 44                 False                  True     True
# 62                 False                  True     True
# homography correctness @3
#  mean:
# 	eval_ll_v16.1_original                      0.425
# 	eval_ll_train_v16.1_lowlight_lr0.0005_5000  0.5
#      [0] _v16.1_original   [1] t_lr0.0005_5000  is_diff
# 20                  True                  True    False
# 34                  True                  True    False
# 40                  True                  True    False
# 44                  True                  True    False
# 62                 False                  True     True
# homography correctness @5
#  mean:
# 	eval_ll_v16.1_original                      0.5875
# 	eval_ll_train_v16.1_lowlight_lr0.0005_5000  0.625
#      [0] _v16.1_original   [1] t_lr0.0005_5000  is_diff
# 20                  True                  True    False
# 34                  True                  True    False
# 40                  True                  True    False
# 44                  True                  True    False
# 62                  True                  True    False
# homography correctness @10
#  mean:
# 	eval_ll_v16.1_original                      0.7625
# 	eval_ll_train_v16.1_lowlight_lr0.0005_5000  0.8
#      [0] _v16.1_original   [1] t_lr0.0005_5000  is_diff
# 20                  True                  True    False
# 34                  True                  True    False
# 40                  True                  True    False
# 44                  True                  True    False
# 62                  True                  True    False
# homography correctness @20
#  mean:
# 	eval_ll_v16.1_original                      0.85
# 	eval_ll_train_v16.1_lowlight_lr0.0005_5000  0.8625
#      [0] _v16.1_original   [1] t_lr0.0005_5000  is_diff
# 20                  True                  True    False
# 34                  True                  True    False
# 40                  True                  True    False
# 44                  True                  True    False
# 62                  True                  True    False
# homography correctness @50
#  mean:
# 	eval_ll_v16.1_original                      0.9125
# 	eval_ll_train_v16.1_lowlight_lr0.0005_5000  0.95
#      [0] _v16.1_original   [1] t_lr0.0005_5000  is_diff
# 20                  True                  True    False
# 34                  True                  True    False
# 40                  True                  True    False
# 44                  True                  True    False
# 62                  True                  True    False
# pair 20
# /home/boat/miniconda3/envs/proxyopt/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# pair 34
# pair 40
# pair 44
# pair 62
