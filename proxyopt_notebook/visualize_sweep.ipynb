# %%
import os
import glob
import numpy as np
import pandas as pd

root = "/home/boat/proxyISP/pytorch-superpoint/logs/"
folder_pattern = (
    "eval_sl_PRETRAINED_SAMEMODELHOMOADAPT_AGGRESSIVEHOMOADAPT_CFANORMALIZE_XHOMOWARP_DETERMHOMOADAPT_train_v16.2-chroma-HumanTunedInitialHype_sunlit_lr0.005_bothLoss_initialHypeHomoAdaptOnly_gradac187_*_HPatchesV4.1"
)

results = []

pattern = os.path.join(root, folder_pattern, "predictions", "result.npz")
print("pattern", pattern)

for path in glob.glob(pattern):
    folder = os.path.basename(os.path.dirname(os.path.dirname(path)))[-22:]

    data = np.load(path)
    correctness = data["correctness"]  # shape (N, 6)
    repeatability = data.get("repeatability")
    mscore = data.get("mscore")
    mAP = data.get("mAP")
    loc_err = data.get("localization_err")  # NEW

    # Threshold averages
    thresh_means = correctness.mean(axis=0)
    avg_overall = thresh_means.mean()

    # Compute mean metrics
    mean_repeat = np.mean(repeatability) if repeatability is not None else np.nan
    mean_mscore = np.mean(mscore) if mscore is not None else np.nan
    mean_map = np.mean(mAP) if mAP is not None else np.nan
    mean_loc_err = np.mean(loc_err) if loc_err is not None else np.nan  # NEW

    results.append(
        (folder, *thresh_means.tolist(), avg_overall, mean_repeat, mean_mscore, mean_map, mean_loc_err)
    )

columns = ["folder", "t1", "t2", "t3", "t4", "t5", "t6", "avg",
           "mean_repeat", "mean_mscore", "mean_map", "mean_loc_err"]
df = pd.DataFrame(results, columns=columns)

# sort by avg correctness
df = df.sort_values(by="avg", ascending=False).reset_index(drop=True)

df
# Out:
# pattern /home/boat/proxyISP/pytorch-superpoint/logs/eval_sl_PRETRAINED_SAMEMODELHOMOADAPT_AGGRESSIVEHOMOADAPT_CFANORMALIZE_XHOMOWARP_DETERMHOMOADAPT_train_v16.2-chroma-HumanTunedInitialHype_sunlit_lr0.005_bothLoss_initialHypeHomoAdaptOnly_gradac187_*_HPatchesV4.1/predictions/result.npz
#                     folder        t1        t2        t3        t4        t5  \
# 0   187_78400_HPatchesV4.1  0.307143  0.550000  0.664286  0.792857  0.821429
# 1   187_78500_HPatchesV4.1  0.307143  0.550000  0.664286  0.792857  0.821429
# 2   187_76800_HPatchesV4.1  0.264286  0.571429  0.700000  0.764286  0.814286
# 3   187_75200_HPatchesV4.1  0.278571  0.557143  0.657143  0.764286  0.821429
# 4   187_75400_HPatchesV4.1  0.264286  0.550000  0.685714  0.771429  0.821429
# 5   187_78200_HPatchesV4.1  0.328571  0.564286  0.628571  0.764286  0.814286
# 6   187_78000_HPatchesV4.1  0.300000  0.542857  0.607143  0.778571  0.828571
# 7   187_77400_HPatchesV4.1  0.300000  0.542857  0.607143  0.778571  0.828571
# 8   187_77000_HPatchesV4.1  0.300000  0.542857  0.607143  0.778571  0.828571
# 9   187_76200_HPatchesV4.1  0.300000  0.550000  0.635714  0.750000  0.814286
# 10  187_75800_HPatchesV4.1  0.300000  0.550000  0.635714  0.750000  0.814286
# 11  187_76600_HPatchesV4.1  0.300000  0.550000  0.635714  0.750000  0.814286
# 12  187_75600_HPatchesV4.1  0.300000  0.535714  0.650000  0.757143  0.807143
# 13  187_77200_HPatchesV4.1  0.321429  0.542857  0.621429  0.735714  0.821429
# 14  187_77600_HPatchesV4.1  0.342857  0.535714  0.607143  0.742857  0.807143
# 15  187_77800_HPatchesV4.1  0.342857  0.535714  0.607143  0.742857  0.807143
# 16  187_76400_HPatchesV4.1  0.342857  0.535714  0.607143  0.742857  0.807143
# 17  187_76000_HPatchesV4.1  0.271429  0.542857  0.635714  0.750000  0.828571
# 18  187_75000_HPatchesV4.1  0.264286  0.550000  0.635714  0.721429  0.807143
#
#           t6       avg  mean_repeat  mean_mscore  mean_map  mean_loc_err
# 0   0.900000  0.672619     0.658009     0.352831  0.771599      1.015121
# 1   0.900000  0.672619     0.658009     0.352831  0.771599      1.015121
# 2   0.878571  0.665476     0.657328     0.353523  0.772838      1.014197
# 3   0.900000  0.663095     0.656847     0.352521  0.769132      1.013393
# 4   0.885714  0.663095     0.658458     0.351815  0.773695      1.014271
# 5   0.864286  0.660714     0.657934     0.353998  0.775098      1.014269
# 6   0.892857  0.658333     0.657496     0.351112  0.774933      1.014125
# 7   0.892857  0.658333     0.657496     0.351112  0.774933      1.014125
# 8   0.892857  0.658333     0.657496     0.351112  0.774933      1.014125
# 9   0.892857  0.657143     0.657814     0.351385  0.768209      1.014361
# 10  0.892857  0.657143     0.657814     0.351385  0.768209      1.014361
# 11  0.892857  0.657143     0.657814     0.351385  0.768209      1.014361
# 12  0.871429  0.653571     0.657055     0.353613  0.771408      1.013546
# 13  0.871429  0.652381     0.657108     0.353283  0.764198      1.013991
# 14  0.864286  0.650000     0.657396     0.352750  0.772491      1.013211
# 15  0.864286  0.650000     0.657396     0.352750  0.772491      1.013211
# 16  0.864286  0.650000     0.657396     0.352750  0.772491      1.013211
# 17  0.871429  0.650000     0.657322     0.349696  0.763302      1.013199
# 18  0.878571  0.642857     0.658697     0.354453  0.770828      1.015724
